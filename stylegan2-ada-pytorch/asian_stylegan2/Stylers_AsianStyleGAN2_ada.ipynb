# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 128, done.
# remote: Total 128 (delta 0), reused 0 (delta 0), pack-reused 128
# Receiving objects: 100% (128/128), 1.12 MiB | 31.88 MiB/s, done.
# Resolving deltas: 100% (57/57), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -qq "/content/drive/MyDrive/Stylers/generated_asian.zip"

# %%
# !cd /content/stylegan2-ada-pytorch

# %%
# !pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.9/205.9 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 64.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: imageio-ffmpeg
#     Found existing installation: imageio-ffmpeg 0.4.8
#     Uninstalling imageio-ffmpeg-0.4.8:
#       Successfully uninstalled imageio-ffmpeg-0.4.8
# ...

# %%
# !python3 /content/stylegan2-ada-pytorch/train.py --aug=noaug --snap=30 --kimg 2000 --resume ffhq256 --outdir /content/stylegan2-ada-pytorch/results --data /content/generated_asian/
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 30,
#   "network_snapshot_ticks": 30,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/generated_asian/",
#     "use_labels": false,
#     "max_size": 10000,
#     "xflip": false,
#     "resolution": 256
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 16384,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
# ...

# %%
# !zip -r asian_style_gan2.zip /content/stylegan2-ada-pytorch/results/
# Out:
# updating: content/stylegan2-ada-pytorch/results/ (stored 0%)
# updating: content/stylegan2-ada-pytorch/results/00000--auto1-kimg2000-noaug-resumeffhq256/ (stored 0%)
# updating: content/stylegan2-ada-pytorch/results/00000--auto1-kimg2000-noaug-resumeffhq256/fakes000360.png (deflated 0%)
# updating: content/stylegan2-ada-pytorch/results/00000--auto1-kimg2000-noaug-resumeffhq256/fakes000840.png (deflated 0%)
# updating: content/stylegan2-ada-pytorch/results/00000--auto1-kimg2000-noaug-resumeffhq256/fakes001080.png (deflated 0%)
# updating: content/stylegan2-ada-pytorch/results/00000--auto1-kimg2000-noaug-resumeffhq256/fakes001920.png (deflated 0%)
# updating: content/stylegan2-ada-pytorch/results/00000--auto1-kimg2000-noaug-resumeffhq256/fakes000480.png (deflated 0%)
# updating: content/stylegan2-ada-pytorch/results/00000--auto1-kimg2000-noaug-resumeffhq256/training_options.json (deflated 61%)
# ...

# %%
from google.colab import files
files.download("/content/asian_style_gan2.zip")

# %%
from time import sleep
from tqdm import tqdm

for _ in tqdm(range(100000)):
    sleep(1)
# Out:
#  38%|███▊      | 37604/100000 [10:28:07<17:22:16,  1.00s/it]
